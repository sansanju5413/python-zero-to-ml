# %% [markdown]
# ## 💰 Personal Expense Tracker (Beginner Level)
#
# 📌 Problem:
#
# Many students don’t track their daily expenses.
# Because of that, they don’t know:
#
# How much money they spend daily
#
# Where they spend more
#
# How much total money is gone

# %% [markdown]
# ## 🎯 Requirements:
#
# Your program should:
# Ask the user for their name.
#
# Show a menu:
# Add Expense
#
# View Total Expense
#
# Exit
#
# ### Allow the user to:
# Enter expense amount
#
# Add it to total
#
# Display total expense when requested.
#
# Keep running until user chooses Exit.
