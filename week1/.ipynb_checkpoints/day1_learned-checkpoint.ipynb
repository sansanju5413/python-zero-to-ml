# %% [markdown]
# ## python basics
# Python is a high-level, interpreted programming language known for its simplicity and readability. It allows developers to write clear programs for both small and large-scale projects

# %%
print("welcome to python")
# Out:
# welcome to python

# %%
print("Hello, I am Sanju.")
print("Starting my Python to ML journey.")
# Out:
# Hello, I am Sanju.
# Starting my Python to ML journey.

# %% [markdown]
# ## variables in python

# %%
#variables
a=6  #assigning a integer to the variable a
print(a)
# Out:
# 6

# %%
name="sanju"  #assigning a string to variable
print(name)
# Out:
# sanju

# %% [markdown]
# ### Data Types in Python

# %% [raw]
# int: For integers --->1,2,3
# float: For floating-point numbers --> 6.14, -0.001
# str: For strings --->"sanju" , "Python"  -->use double braces for integer
# bool: For boolean values -->True or False

# %%
# type 
a=213
name="sanju"
age=23.5
car=True
print("a", type(a))
print(type(name))
print(type(age))
print(type(car))
# Out:
# a <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
#typeconversion
age=21
print(type(age))
print(int(age))
print(type(str(age)))
# Out:
# <class 'int'>
# 21
# <class 'str'>

# %%
age="22.4"
print(type(age))
agee=float(age)
print(type(agee))
# Out:
# <class 'str'>
# <class 'float'>

# %% [markdown]
# ### Input/Output

# %%
#input
name=input("enter your name")
print(name)
# Out:
# enter your name sanju
# sanju

# %%
age=input("enter your age")
print(age)
# Out:
# enter your age 21
# 21

# %%
# float
age=float(input("enter your age"))
print(age)
# Out:
# enter your age 21
# 21.0

# %%
# float
age=float(input("enter your age"))
print(age)
# Out:
# enter your age 23.5
# 23.5

# %%
#Output

# %%
#using cocatinating method
name="sanju"
age=21
print("name is "+ name +" and age is "+ age)  #it will give error becouse we cant able to cocatenate str to int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 name="sanju"
#       2 age=21
# ----> 3 print("name is "+ name +" and age is "+ age)  #it will give error becouse we cant able to cocatenate str to int
#
# TypeError: can only concatenate str (not "int") to str

# %%
#using cocatinating method
name="sanju"
age=21
print("name is "+ name +" and age is "+ str(age))  #needs to typecovert like this  age to str(age)
# Out:
# name is sanju and age is 21

# %%
# use f-strings or formatted string literals
print(f"name is {name} and age difference is {age}")
# Out:
# name is sanju and age difference is 21

# %%
#string repetition
name="sanju"*3
print(name)
# Out:
# sanjusanjusanju

# %% [raw]
# String Methods:
# upper(): Converts a string to uppercase.
# lower(): Converts a string to lowercase.
# strip(): Removes leading or trailing spaces from a string.
# replace(): Replaces a substring with another string-->replaces a old with the new string

# %%
name="  SanJUHs Is A ProGramMer"
print(name.upper())
# Out:
#   SANJUHS IS A PROGRAMMER

# %%
print(name.lower())
# Out:
#   sanjuhs is a programmer

# %%
print(name.strip())
# Out:
# SanJUHs Is A ProGramMer

# %%
print(name.replace("ProGramMer","developer"))
# Out:
#   SanJUHs Is A developer

# %%
#accessing a string 
print(name[2])
# Out:
# S

# %%
print(name[-1])
# Out:
# r

# %%
#slicing
print(name[0:5:2])
# Out:
#  Sn

# %%
print(name[0:5])
# Out:
#   San
