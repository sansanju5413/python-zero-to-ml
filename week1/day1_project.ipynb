# %% [markdown]
# ## 🪪 Digital ID Card Generator
# 📌 Problem:
#
# Create a Python program that:
#
# Asks the user for:
#
# Full Name
#
# Age
#
# College Name
#
# Branch
#
# City
#
# Stores each value in separate variables.
#
# Prints a formatted “Digital ID Card” like this:

# %% [markdown]
# ### 🎯 Rules
#
# Use only variables.
#
# Use only input().
#
# Use only print().
#
# No if-else.
#
# No loops.
#
# No operators.

# %%
full_name=input("Name: ")
age=input("Age: ")
college_name=input("College: ")
branch=input("Branch: ")
city=input("City: ")

print("----------------------")
print("      STUDENT ID CARD")
print("----------------------")
print("Name   :", full_name)
print("Age    :", age)
print("College:", college_name)
print("Branch :", branch)
print("City   :", city)
print("----------------------")
# Out:
# Name:  sanju
# Age:  2
# College:  gec clk
# Branch:  aiml
# City:  chalkere
# ----------------------
#       STUDENT ID CARD
# ----------------------
# Name   : sanju
# Age    : 2
# College: gec clk
# Branch : aiml
# City   : chalkere
# ----------------------
